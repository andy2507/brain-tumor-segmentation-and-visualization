# %%
import pandas as pd

# %%
df = pd.read_csv('/home/andrea/Notebooks/FYP/frontend_html_css/BraTS19_CBICA_ANG_1/results/prediction_yolo_bboxes.csv')

# %%
df
# Out:
#      slice  class  xmin  ymin  xmax  ymax
# 0        0      1     1     0   235   239
# 1        1      1     0     0   235   239
# 2        2      1     0     0   237   240
# 3        3      1     0     0   237   240
# 4        4      1     0     0   239   240
# ..     ...    ...   ...   ...   ...   ...
# 150    150      1     3     1   240   237
# 151    151      1     3     1   240   237
# 152    152      1     3     1   240   237
# 153    153      1     3     1   240   237
# 154    154      1     3     1   240   237
#
# [155 rows x 6 columns]

# %%
df.transpose().to_dict()
# Out:
# {0: {'slice': 0, 'class': 1, 'xmin': 1, 'ymin': 0, 'xmax': 235, 'ymax': 239},
#  1: {'slice': 1, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 235, 'ymax': 239},
#  2: {'slice': 2, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 237, 'ymax': 240},
#  3: {'slice': 3, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 237, 'ymax': 240},
#  4: {'slice': 4, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 239, 'ymax': 240},
#  5: {'slice': 5, 'class': 1, 'xmin': 1, 'ymin': 0, 'xmax': 240, 'ymax': 240},
#  6: {'slice': 6, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 240, 'ymax': 240},
#  7: {'slice': 7, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 240, 'ymax': 240},
#  8: {'slice': 8, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 239, 'ymax': 240},
#  9: {'slice': 9, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 239, 'ymax': 240},
#  10: {'slice': 10, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 239, 'ymax': 240},
#  11: {'slice': 11, 'class': 1, 'xmin': 0, 'ymin': 0, 'xmax': 239, 'ymax': 240},
# ...

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>slice</th>
#       <th>class</th>
#       <th>xmin</th>
#       <th>ymin</th>
#       <th>xmax</th>
#       <th>ymax</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>235</td>
#       <td>239</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>235</td>
#       <td>239</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>237</td>
#       <td>240</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>237</td>
#       <td>240</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>1</td>
# ...
